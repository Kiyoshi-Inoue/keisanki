# %%
from sklearn.model_selection import KFold
import random
import numpy as np
from sklearn.preprocessing import StandardScaler
import function
import matplotlib.pyplot as plt
import math
import tqdm
import rpy2.robjects as robjects

# %%
install.packages("PCLassoReg", dependencies=TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 install.packages("PCLassoReg", dependencies=TRUE)
#
# NameError: name 'install' is not defined

# %%
base = robjects.packages.importr('PCLassoReg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 base = robjects.packages.importr('PCLassoReg')
#
# AttributeError: module 'rpy2.robjects' has no attribute 'packages'

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rpy2 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (3.5.5)
# Requirement already satisfied: cffi>=1.10.0 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (1.15.1)
# Requirement already satisfied: tzlocal in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (4.3)
# Requirement already satisfied: pytz in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (2023.3)
# Requirement already satisfied: jinja2 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (3.1.2)
# Requirement already satisfied: pycparser in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from cffi>=1.10.0->rpy2) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from jinja2->rpy2) (2.1.2)
# Requirement already satisfied: pytz-deprecation-shim in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from tzlocal->rpy2) (0.1.0.post0)
# Requirement already satisfied: tzdata in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from pytz-deprecation-shim->tzlocal->rpy2) (2023.3)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade rpy2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rpy2 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (3.5.5)
# Collecting rpy2
#   Using cached rpy2-3.5.11.tar.gz (216 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-r_q8kdn4/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/21/83/58efe42e96397d441609e411d37392dc68198f1a2ff7663c21a1cb07e6a8/rpy2-3.5.11.tar.gz#sha256=0d3e554dac8f4e55a28932f2946341aae3e02894304e1198547222aa86b89e21 (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/21/83/58efe42e96397d441609e411d37392dc68198f1a2ff7663c21a1cb07e6a8/rpy2-3.5.11.tar.gz#sha256=0d3e554dac8f4e55a28932f2946341aae3e02894304e1198547222aa86b89e21 has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
#   Using cached rpy2-3.5.10.tar.gz (215 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-lf2m7oyh/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/fe/1c/18c718a1365bedc10438810637b5d735737c697998d5c163cc58edb6f1ee/rpy2-3.5.10.tar.gz#sha256=f81f0afb01e3c6f515c09573bc585c0e1c7e385ec81415ce0a62268c605ec7fc (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/fe/1c/18c718a1365bedc10438810637b5d735737c697998d5c163cc58edb6f1ee/rpy2-3.5.10.tar.gz#sha256=f81f0afb01e3c6f515c09573bc585c0e1c7e385ec81415ce0a62268c605ec7fc has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
#   Using cached rpy2-3.5.9.tar.gz (215 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-zuplevvx/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/f9/d4/f817a523c4168c826a816f89a5a080fa2fd7ad939dbfece5eb5d01235070/rpy2-3.5.9.tar.gz#sha256=89a0d7e340657795558e0db6bf9d8f1395428ba118af9023515dda928e6944f0 (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/f9/d4/f817a523c4168c826a816f89a5a080fa2fd7ad939dbfece5eb5d01235070/rpy2-3.5.9.tar.gz#sha256=89a0d7e340657795558e0db6bf9d8f1395428ba118af9023515dda928e6944f0 has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
#   Using cached rpy2-3.5.8.tar.gz (214 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-ydmxuzil/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/a2/63/442160f69e1f163c24a73a3796b9ebd63c217b73941e4888734687e225d4/rpy2-3.5.8.tar.gz#sha256=22611f21bc52798087fb98309705f1a25cfbe8bfd27fbfeeea01f3d352fddb29 (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/a2/63/442160f69e1f163c24a73a3796b9ebd63c217b73941e4888734687e225d4/rpy2-3.5.8.tar.gz#sha256=22611f21bc52798087fb98309705f1a25cfbe8bfd27fbfeeea01f3d352fddb29 has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
#   Using cached rpy2-3.5.7.tar.gz (213 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-upka3jir/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/8b/39/4a9d9e59ba062f156a642af7271bed418584406a6e65c3a23d1ded8c4a77/rpy2-3.5.7.tar.gz#sha256=87a4090379b4fc34e7f3a43471730906776c37398887086a80357d64fdd0654b (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/8b/39/4a9d9e59ba062f156a642af7271bed418584406a6e65c3a23d1ded8c4a77/rpy2-3.5.7.tar.gz#sha256=87a4090379b4fc34e7f3a43471730906776c37398887086a80357d64fdd0654b has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
#   Using cached rpy2-3.5.6.tar.gz (211 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/06/qg_hq9dd7xb7qxg6y5b1cq9r0000gn/T/pip-build-env-fczjqrse/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package rpy2 produced metadata for project name unknown. Fix your #egg=rpy2 fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/ae/bd/2606e674ef0760fbe832e32274d23a9e2ca5192ab1d43a04ee5e24cf7045/rpy2-3.5.6.tar.gz#sha256=3404f1031d2d8ff8a1002656ab8e394b8ac16dd34ca43af68deed102f396e771 (from https://pypi.org/simple/rpy2/) (requires-python:>=3.7). Requested unknown from https://files.pythonhosted.org/packages/ae/bd/2606e674ef0760fbe832e32274d23a9e2ca5192ab1d43a04ee5e24cf7045/rpy2-3.5.6.tar.gz#sha256=3404f1031d2d8ff8a1002656ab8e394b8ac16dd34ca43af68deed102f396e771 has inconsistent name: filename has 'rpy2', but metadata has 'UNKNOWN'
# Requirement already satisfied: cffi>=1.10.0 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (1.15.1)
# Requirement already satisfied: tzlocal in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (4.3)
# Requirement already satisfied: jinja2 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (3.1.2)
# Requirement already satisfied: pytz in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from rpy2) (2023.3)
# Requirement already satisfied: pycparser in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from cffi>=1.10.0->rpy2) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from jinja2->rpy2) (2.1.2)
# Requirement already satisfied: pytz-deprecation-shim in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from tzlocal->rpy2) (0.1.0.post0)
# Requirement already satisfied: tzdata in /Users/inouekiyoshi/Library/Python/3.9/lib/python/site-packages (from pytz-deprecation-shim->tzlocal->rpy2) (2023.3)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
